# %%
user_list = [
'박도윤:bde1902:10.16.41.3:DEPT10003:품질경영처',
'최예준:chiez1903:10.16.41.4:DEPT10004:기획처',
'정시우:zse1904:10.16.41.5:DEPT10005:경영전략처',
'강하준:khz1905:10.16.41.6:DEPT10006:지속성장처',
'조주원:zze1906:10.16.41.7:DEPT10007:마케팅처',
'윤지호:ezh1907:10.16.41.8:DEPT10008:인사처',
'장지후:zzh1908:10.16.41.9:DEPT10009:법무실',
'임준우:eze1909:10.16.41.10:DEPT10010:계약구매실',
'한준서:hzs1910:10.16.41.11:DEPT10011:정보보안실',
'오건우:eke1911:10.16.41.12:DEPT10012:안전관리실',
'서도현:sdh1912:10.16.41.13:DEPT10013:재무처',
'신현우:she1913:10.16.41.14:DEPT10014:상생노무처',
'권지훈:kzh1914:10.16.41.15:DEPT10015:인재개발원',
'황우진:hez1915:10.16.41.16:DEPT10016:원자력사업운영실',
'안선우:ese1916:10.16.41.17:DEPT10017:원전안전센터',
'송서진:ssz1917:10.16.41.18:DEPT10018:건설사업처',
'류유준:rez1918:10.16.41.19:DEPT10019:해외사업처',
'전연우:zee1919:10.16.41.20:DEPT10020:원전O&M사업처',
'홍민재:hmz1920:10.16.41.21:DEPT10021:SI 사업처',
'고현준:khz1921:10.16.41.22:DEPT10022:사후관리사업처',
'문은우:mee1922:10.16.41.23:DEPT10023:미래성장사업처',
'양정우:eze1923:10.16.41.24:DEPT10024:원자력총괄기술처',
'손시윤:sse1924:10.16.41.25:DEPT10025:원자력기술실',
'배승우:bse1925:10.16.41.26:DEPT10026:기계기술실',
'조승현:zsh1926:10.16.41.27:DEPT10027:배관기술실',
'백준혁:bzh1927:10.16.41.28:DEPT10028:전기기술실',
'허지환:hzh1928:10.16.41.29:DEPT10029:계측제어기술실',
'유윤우:eee1929:10.16.41.30:DEPT10030:구조부지기술실',
'남승민:nsm1930:10.16.41.31:DEPT10031:건축환경기술실',
'심유찬:sechi1931:10.16.41.32:DEPT10032:사업관리기술실',
'노지우:nze1932:10.16.41.33:DEPT10033:안전성평가기술실',
'정이준:zez1933:10.16.41.34:DEPT10034:에너지사업운영실',
'하민성:hms1934:10.16.41.35:DEPT10035:에너지사업개발처',
'곽준영:kze1935:10.16.41.36:DEPT10036:융복합사업처',
'성시후:ssh1936:10.16.41.37:DEPT10037:신재생사업처',
'차진우:chize1937:10.16.41.38:DEPT10038:에너지총괄기술처',
'주수호:zsh1938:10.16.41.39:DEPT10039:기계배관환경기술실',
'우지원:eze1939:10.16.41.40:DEPT10040:전기계측기술실',
'구수현:ksh1940:10.16.41.41:DEPT10041:토목건축기술실',
'신재윤:sze1941:10.16.41.42:DEPT10042:원자로사업운영실',
'임시현:esh1942:10.16.41.43:DEPT10043:원자로설계관리실',
'라동현:rdh1943:10.16.41.44:DEPT10044:원자로건설사업처',
'전태윤:ztuee1944:10.16.41.45:DEPT10045:가동원전사업처',
'민이안:mee1945:10.16.41.46:DEPT10046:신기술사업처',
'유민규:emk1946:10.16.41.47:DEPT10047:원자로총괄기술처',
'진한결:zhk1947:10.16.41.48:DEPT10048:유체계통설계실',
'지재원:zze1948:10.16.41.49:DEPT10049:기계설계실',
'엄민우:eme1949:10.16.41.50:DEPT10050:계측제어설계실',
'채재민:chizm1950:10.16.41.51:DEPT10051:안전해석실',
'원은찬:eechi1951:10.16.41.52:DEPT10052:기술관리실',
    
    str_digit =  '0' + str(digit) if digit < 10 else str(digit)
        
    print( f'\'15:01:{str_digit}\',' )

# %%
proc_date = '20230502'

times = [
    # '00:01:45', # 새벽 접속
    # '02:10:19', # 새벽 접속
    # '19:20:20', # 오후 19시 접속
    # '21:05:10', # 오후 21시 접속
    # '23:59:59', # 오후 23시 접속
    '15:01:00', # 오후 3시 접속
    '15:01:01',
    '15:01:02',
    '15:01:03',
    '15:01:04',
    '15:01:05',
    '15:01:06',
    '15:01:07',
    '15:01:08',
    '15:01:09',
    '15:01:10',
    '15:01:11',
    '15:01:12',
    '15:01:13',
    '15:01:14',
    '15:01:15',
    '15:01:16',
    '15:01:17',
    '15:01:18',
    '15:01:19',
    '15:01:20',
    '15:01:21',
    '15:01:22',
    '15:01:23',
    '15:01:24',
    '15:01:25',
    '15:01:26',
    '15:01:27',
    '15:01:28',
    '15:01:29',
    '15:01:30',
    '15:01:31',
    '15:01:32',
    '15:01:33',
    '15:01:34',
    '15:01:35',
    '15:01:36',
    '15:01:37',
    '15:01:38',
    '15:01:39',
    '15:01:40',
    '15:01:41',
    '15:01:42',
    '15:01:43',
    '15:01:44',
    '15:01:45',
    '15:01:46',
    '15:01:47',
    '15:01:48',
    '15:01:49',
    '15:01:50',
    '15:01:51',
    '15:01:52',
    '15:01:53',
    '15:01:54',
    '15:01:55',
    '15:01:56',
    '15:01:57',
    '15:01:58',
    '15:01:59',
]

# %%
def as_user( user_name, user_id, user_ip, dept_code, dept_name ):
    data = list()
    for time in times:
        proc_time = ''.join( time.split( ':' ) )
        datum = f' ( \'{user_name}\', \'{user_id}\', \'{dept_code}\', \'{dept_name}\', \'{proc_time}\', \'{proc_date}\' )'
        data.append( datum )
                
    return ', '.join( data )

# %%
insert_prefix = \
'insert into biz_log_summary_demo ( log_seq, emp_user_name, emp_user_id, dept_id, dept_name, proc_time, proc_date ) values '
insert_postfix = ', '.join( [ as_user( *(user.split(':')) ) for user in user_list ] )
print( insert_prefix )
print( insert_postfix )
# Out:
# insert into biz_log_summary_demo ( log_seq, emp_user_name, emp_user_id, dept_id, dept_name, proc_time, proc_date ) values
# ...

# %%
# !python -m pip install Psycopg2
# Out:
# ...
#                                               0.0/1.2 MB ? eta -:--:--
#      --------------------                     0.6/1.2 MB 12.6 MB/s eta 0:00:01
#      ---------------------------------------  1.2/1.2 MB 12.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.2/1.2 MB 9.3 MB/s eta 0:00:00
# ...

# %%
import psycopg2

db_info = {
    database : "summon1",
    host : "127.0.0.1",
    user : "psm",
    password : "psm123",
    port : "5432"
}

conn = psycopg2.connect( **db_info )
cursor = conn.cursor()
log_seq = cursor.fetchone("SELECT log_seq FROM biz_log_summary_demo limit 1")

log_seq += 1

def as_user( user_name, user_id, user_ip, dept_code, dept_name ):
    data = list()
    for time in times:
        proc_time = ''.join( time.split( ':' ) )
        datum = f' ( \'{log_seq}\', \'{user_name}\', \'{user_id}\', \'{dept_code}\', \'{dept_name}\', \'{proc_time}\', \'{proc_date}\' )'
        log_seq += 1
        data.append( datum )
                
    return ', '.join( data )

insert_prefix = \
'insert into biz_log_summary_demo ( log_seq, emp_user_name, emp_user_id, dept_id, dept_name, proc_time, proc_date ) values '
insert_postfix = ', '.join( [ as_user( *(user.split(':')) ) for user in user_list ] )

cursor.execute( insert_prefix +  insert_postfix )

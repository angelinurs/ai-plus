# %%
sheet = \
'''
차단시간	Zone	VPC	차단이벤트	프로토콜	공격자 IP	공격자 Port	타겟 IP	타겟 Port	위험도	공격건수	예외
2023-10-09 02:52:09 (UTC+09:00)	KR-1	easycerti-vpc-2	Identified Suspicious Command Injection Attack	TCP	198.18.0.172	45588	198.18.1.250	8080	Critical	1	예외요청
2023-10-08 22:25:52 (UTC+09:00)	KR-1	easycerti-vpc-2	Identified Suspicious Command Injection Attack	TCP	198.18.0.172	50984	198.18.1.250	8080	Critical	1	예외요청
2023-10-08 21:18:54 (UTC+09:00)	KR-1	easycerti-vpc-2	Identified Directory Traversal Sequence In URI	TCP	198.18.0.172	41636	198.18.1.237	8080	Critical	1	예외요청
2023-10-08 20:05:03 (UTC+09:00)	KR-1	easycerti-vpc-2	Identified Directory Traversal Sequence In URI	TCP	198.18.0.172	17066	198.18.1.58	8080	Critical	1	예외요청
2023-10-08 17:46:58 (UTC+09:00)	KR-1	easycerti-vpc-2	Identified Directory Traversal Sequence In URI	TCP	10.0.3.20	13391	198.18.1.250	8080	Critical	1	예외요청
2023-10-07 13:34:03 (UTC+09:00)	KR-1	easycerti-vpc-2	Identified Suspicious Command Injection Attack	TCP	10.0.3.20	19599	198.18.1.253	8080	Critical	1	예외요청
'''

# %%
sheet.split('\n')

data = []
for line in sheet.split('\n'):
    data.append( line.split('\t') )

data[1:-1]

# %%
import pandas as pd

df = pd.DataFrame( data=data[2:-1], columns=data[1])
df

# %%
'egrep ' + '|'.join(list(df['타겟 IP'].unique()))
# example
#  k get pod -o wide | egrep "198.18.1.250|198.18.1.237|198.18.1.58|198.18.1.253|198.18.1.36|198.18.1.35|198.18.1.162"

# %%
text = \
'''
1.1) Kubernetes Version: 현재 k8s 버전이 1.25.8 이며, 1.26.8 이상을 권고
  - [MSP] NCP 버전 업데이트 일정 유무 소명 필요
  - [CSP] 12월 21일 공공 정기 배포에 최신 버전 출시 예정이며, 이후 업그레이드 진행이 가능합니다.
  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.
  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.

1.2) ubuntu Version: 현재 ubuntu OS 이미지 20.04.6 LTS 버전의 커널 "5.4.0.148"에서 "5.4.0.-159.176" 업그레이드 권고 
  - [MSP] MSP 커널 업데이트 작업 지원 가능 하나, 장애 시 복구 지원의 제약 존재
  - [CSP] 12월 21일 공공 정기 배포에 반영 예정이며, 이후 신규 노드풀 추가 후 전환 진행이 가능합니다.
  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.
  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.

1.3) postgres Version: Cloud DB for PostgreSQL 서비스의 PostgreSQL 13.12 버전 권고
  - [MSP] NCP 버전 업데이트 일정 유무 소명 필요
  - [CSP] 해당 사항은 일정 확인의 답변이 지연이 되고 있습니다.
  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.
  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.

1.4) Ncloud Simple RabbitMQ: Ncloud Simple RabbitMQ 서비스에서 TLS/SSL을 지원하고 있지 않음
  - [MSP] NCP 기능 업데이트 일정 유무 소명 필요, 해당 서비스 TLS/SSL 지원 계획 없을 시, 별도 PLAN_B 고민 필요
  - [CSP] 현재, 상품에서 해당 기능 미지원으로 적용 불가, 내부적으로 정해진 개발 일정이 없어서 PLAN B 고민이 필요해보입니다.
  > 해당 서비스의 경우 관리형(Managed) 서비스 이기 때문에 별도 config 수정 불가
  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.
  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.

1.5) MAC Address 접근 제한: SSL_VPN 접속 시, MAC-Address 접근 제한
  - [MSP] SSL_VPN 을 통한 MAC-Address 접근 제한을 하기 위해, "문의하기" 통해 수동 설정 가능
  - [CSP] 공공 클라우드 SSL VPN 상품은 MAC 인증 기능을 수작업으로 지원하고 있습니다. Classic/VPC에 따라 동작 방식에 차이가 있으며, 수작업이므로, 설정 관련 요청은 고객 문의로만 가능합니다.
  > 관련 내용에 대해 확인되시어, 연구원님 측에서 요청 진행 하신것으로 인지하겠습니다.
  > 해당 사항에 대해 조치가 되었을 것으로 인지하고 있습니다.

1.6) Worker Node Server: Worker Node VM 에 CCE 조치 설정
  - [MSP] MSP 지원 가능한 부분
  - [CSP] ncp kubernetes service는 master 만 navercloud 에서 관리합니다. woker node에 대해서는 고객사에서 직접 조치가 필요합니다.
  - [CSP_참고] nks initscript 가이드 참고용도로 전달 드립니다. (링크 : https://guide-gov.ncloud-docs.com/docs/k8s-k8suse-init-script)
  > 관련 사항으로 패스워드 복잡성 적용 시, "PEM 키를 통한 패스워드 확인 가능 유무", "불가능할 시 확인 및 조치 가능 방법" 에 대해 확인 해보도록 하겠습니다.
  > 관련 사항으로 패스워드 복잡성 적용 시, "PEM 키를 통한 패스워드 확인 가능 유무" 내부적으로 테스트 해보도록 하겠습니다.
  > 관련 사항으로 initScript 기능에 대해 , 내부 테스트 환경 구성하여 테스트 후, 테스트 결과에 대해 안내 드릴 수 있도록 하겠습니다.
  > [9월 27일] 하기와 같이 안내 드렸습니다.

1.7) system account 로 실행되는 kubeconfig 설정: kubeconfig rbac 설정
  - [MSP] MSP 지원 가능한 부분이며, kubectl 명령에 대한 컨트롤 제약 부분인지, API 통신을 위한 IAM 통한 Sub-Account 의 제약 부부분인지 확인 필요
  - [CSP] woker node에 대해서는 고객사에서 직접 조치가 필요합니다.
  - [CSP_참고] IAM 인증 사용자 관리 가이드 참고 용도로 전달 드립니다. (링크 : https://guide-gov.ncloud-docs.com/docs/k8s-iam-auth-management)
  > 관련 내용에 대해 조치 방법에 대해 고려하시는 부분이 있으신것으로 인지하였으며, 추가 문의사항이 있으시면 말씀 부탁드립니다.
  > 해당 사항에 대해 조치가 되었을 것으로 인지하고 있습니다.

1.8) 공인 인증서 회전: 
  - 해당 내용에 대해서 조금더 상세한 부연 설명이 필요합니다.
  > SSL 인증서에 대한 적용 부분으로 이해하였으며, 인증서 자체가 변경되는 부분이기 때문에 수동 업데이트가 필요할 것 입니다.
  > 교체 및 갱신 시 확인 또는 고려될 사항이 있으시면 말씀 부탁드리겠습니다.
  > 해당 사항에 대해 SSL 인증서 자체의 변경이 이루어지기 때문에 수동 업데이트가 필요하여 증빙하실 것으로 인지하고 있습니다.

1.9) 주계정 access-key, secret key: 일정 기간별 access, secret key 변경 시, kubeconfig 자동 설정 유무 문의 예상
  - [MSP] 불가능 할 것으로 생각되며, 매번 수동으로 업데이트 필요
  - [CSP] 키 자동 변경 부분은 지원되고 있지않으며, 수동설정 필요합니다. 키 변경후 신규 키를, Kubeconfig에서 지정한 ncloud configure proifle(미 지정시 Default)에 수정해 주시면 됩니다.
  > 해당 사항에 대해선 아쉽지만, 수동 업데이트 설정 변경이 필요한 부분입니다.
  > 해당 사항에 대해 조치가 되었을 것으로 인지하고 있습니다.
'''

# %%
text2 = \
'''
2.1) 10.3.2 사용자 인증: 강화된 인증(OTP) 기능에 따른 확약서 요청
  - 현재 네이버클라우드 측은 2FA 인증으로 ID/PWD 와, 등록된 메일/핸드폰 으로 인증번호 OTP 를 통하여 로그인 기능을 제공 하고 있습니다.
  - 평가기관 측에서 요구하는 강화된 인증(OTP) 는 어떤 기준으로의 "강화된 인증"을 의미하는 부분일지요?
  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.
  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.

2.2) 11.1.2 네트워크 모니터링 및 통제:
  - "ACL 설정시 default automatically created, don't delete it 문제" 에 대해서 저희 및 네이버클라우드 측에 확인 요청을 해볼 캡쳐 내용이 있을까요?
  - 더불어 엑셀 파일의 문제점 내용을 보면, "임의로 생성된 정책" 및 "과도하게 허용된 룰셋" 에 대해 이행조치만 하면 되는 부분일까요?
  > 제가 사용하는 테스트 계정 통해, ACG 및 NACL 확인해보았지만, "default automatically created, don't delete it" 문구확인을 못하였습니다.
  > 번거로우시겠지만, 해당 문구에 대해 확인할 수 있는 부분 혹은 캡쳐하나 보내주실 수 있으실까요?
  > [9월 27일] 하기와 같이 안내 드렸습니다.
=====
위 사항으로는 NKS 클러스터 생성의, Node 생성 시 해당 생성되는 노드에 자동으로 적용되는 ACG 의 표기된 문구인것 같습니다.
참조 링크: https://guide-gov.ncloud-docs.com/docs/k8s-k8suse-acg

위의 링크 보시면 "기본 ACG 규칙" 이 말씀하시는것 같으시고, CSAP 인증 심사 때는 해당 규칙이 아닌, 서비스 포트만 정의되어야 하는것으로 인지가 됩니다.
위 링크의 "기본 ACG 규칙 (automatically created, don't delete it)" 은 삭제가 가능하며, 동일 화면에 "필수 ACG 규칙" 보시면 k8s 의 컴포넌트별 포트가 정의되어있습니다.

해당 "필수 ACG 규칙" 을 적용 한다음, "기본 ACG 규칙 (automatically created, don't delete it)" 을 삭제하여 서비스가 정상적인지 확인 후, 최종 반영순으로 조치가 이루어지면 되겠습니다.
=====

2.3) 11.1.3 네트워크 정보보호시스템 운영: 콘솔 관리계정 정책
  - 관리콘솔계정 및 NACL, ACG 정책 항목의 지적을 한 문제점들에 대해 조치 및 증적자료에 대해 준비가 되면 좋을 것 같습니다.
  - 클라우드 관리접속 콘솔은 IP를 통한 접속 통제를 할 수 있으며, MAC 주소를 통한 접속 제한 기능은 현재 지원되지 않습니다.
  > 해당 항목에 대해선 처리가 된 것으로 이해하였습니다.
  > 해당 사항에 대해 조치가 되었을 것으로 인지하고 있습니다.

2.4) 11.1.4 네트워크 암호화
  - Ncloud Simple RabbitMQ 서비스 TLS/SSL 암호화 통신 불가능으로 인한 PLAN_B 고민 필요
  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.
  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.
'''

# %%
text.split('\n')

l = list()
d = dict()

for line in text.split('\n')[1:]:
    if not bool(len(line)): 
        d.update({
            'title' : title,
            'sub' : sub,
            'sub2' : sub2,
        })
        l.append(d.copy())
        continue
    if not line.startswith(' '):
        title = line
        sub = []
        sub2 = []
    if line.startswith('  -'):
        sub.append( line )
    if line.startswith('  >'):
        sub2.append( line )

# print( *l, sep='\n' )
# print( l[0].keys() )

results = []
for content in l:
    results.extend(list(map(lambda x : (content.get('title'), x[0], x[1] ), zip(content.get('sub'), content.get('sub2')))))

print( *results, sep='\n' )
# Out:
# ('1.1) Kubernetes Version: 현재 k8s 버전이 1.25.8 이며, 1.26.8 이상을 권고', '  - [MSP] NCP 버전 업데이트 일정 유무 소명 필요', '  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.')
# ('1.1) Kubernetes Version: 현재 k8s 버전이 1.25.8 이며, 1.26.8 이상을 권고', '  - [CSP] 12월 21일 공공 정기 배포에 최신 버전 출시 예정이며, 이후 업그레이드 진행이 가능합니다.', '  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.')
# ('1.2) ubuntu Version: 현재 ubuntu OS 이미지 20.04.6 LTS 버전의 커널 "5.4.0.148"에서 "5.4.0.-159.176" 업그레이드 권고 ', '  - [MSP] MSP 커널 업데이트 작업 지원 가능 하나, 장애 시 복구 지원의 제약 존재', '  > 해당 사항에 대해 네이버클라우드 측 통하여, "업데이트 시 적용 계획" 문구 중점적으로 확약서에 대해 받아볼 수 있을지 요청해보도록 하겠습니다.')
# ('1.2) ubuntu Version: 현재 ubuntu OS 이미지 20.04.6 LTS 버전의 커널 "5.4.0.148"에서 "5.4.0.-159.176" 업그레이드 권고 ', '  - [CSP] 12월 21일 공공 정기 배포에 반영 예정이며, 이후 신규 노드풀 추가 후 전환 진행이 가능합니다.', '  > 네이버클라우드 담당자분께 내용 공유드렸으며, 내부 검토 중입니다.')
# ...

# %%
pd.DataFrame( data=results, columns=('title', 'sub', 'sub2')) \
  .to_excel('./MSP-didim-회신.xlsx', sheet_name = '00.기술 논의 항목 정리', index=False )

# %%
def data_to_excel( text, sheet_name, writer ):
    text.split('\n')

    l = list()
    d = dict()

    for line in text.split('\n')[1:]:
        if not bool(len(line)): 
            d.update({
                'title' : title,
                'sub' : sub,
                'sub2' : sub2,
            })
            l.append(d.copy())
            continue
        if not line.startswith(' '):
            title = line
            sub = []
            sub2 = []
        if line.startswith('  -'):
            sub.append( line )
        if line.startswith('  >'):
            sub2.append( line )

    # print( *l, sep='\n' )
    # print( l[0].keys() )

    results = []
    for content in l:
        results.append((content.get('title'), '\n'.join(content.get('sub') ), '\n'.join(content.get('sub2') ) ))
        # results.extend(list(map(lambda x : (content.get('title'), x[0], x[1] ), zip(content.get('sub'), content.get('sub2')))))

    # pd.DataFrame( data=results, columns=('title', 'sub', 'sub2')) \
    #   .to_excel( writer, sheet_name = sheet_name, index=False )

    pd.DataFrame( data=results, columns=('title', 'sub', 'sub2')) \
      .to_csv( writer, encoding='cp949', index=False )

# %%
# xlxs_dir = './MSP-didim-회신.xlsx'

# with pd.ExcelWriter(xlxs_dir) as writer:
#     sheet_name = '00.기술 논의 항목 정리'
#     data_to_excel( text, sheet_name, writer )

#     sheet_name = '01.서면현장평가 보완'
#     data_to_excel( text2, sheet_name, writer )


sheet_name = '00.기술 논의 항목 정리'
data_to_excel( text, sheet_name, f'./{sheet_name}-MSP-didim-회신.csv' )

sheet_name = '01.서면현장평가 보완'
data_to_excel( text2, sheet_name, f'./{sheet_name}-MSP-didim-회신.csv' )

# %%
application_yml = \
'''
"id","application","profile","label","key","value","created_at","modified_at","update_datetime"
27866,rparser,svc192,company_description,spring.devtools.restart.enabled,false,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27867,rparser,svc192,company_description,spring.main.web-application-type,none,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27868,rparser,svc192,company_description,spring.main.allow-bean-definition-overriding,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27869,rparser,svc192,company_description,spring.datasource.driver-class-name,org.postgresql.Driver,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27870,rparser,svc192,company_description,app.FILEINPATH,/usr/local/PSM/logs/ResponseLog/in/,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27871,rparser,svc192,company_description,app.FILEWORKPATH,/usr/local/PSM/logs/ResponseLog/work/,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27872,rparser,svc192,company_description,app.FILEOUTPATH,/usr/local/PSM/logs/ResponseLog/out/,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27873,rparser,svc192,company_description,app.FAILPATH, /usr/local/PSM/logs/ResponseLog/fail/,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27874,rparser,svc192,company_description,app.MOVEPATH,/usr/local/PSM/logs/ResponseLog/after-logs/,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27875,rparser,svc192,company_description,app.PRIVLOGPATH,/usr/local/PSM/logs/ResponseLog/priv-logs/  ,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27876,rparser,svc192,company_description,app.WORKTHREADSNUM,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27877,rparser,svc192,company_description,app.FILENAME,EZ_PRIV_LOG,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27878,rparser,svc192,company_description,app.PRIVENCKEY,B64B0D57F9166809B2BCD996278A2AEFA49630BE4505B81225E78087C6659643,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27879,rparser,svc192,company_description,app.READTHREADSNUM,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27880,rparser,svc192,company_description,app.THREADSLEEPTIME,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27881,rparser,svc192,company_description,app.FILEDELETEOPTION,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27882,rparser,svc192,company_description,app.TARGETSYSTEM,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27883,rparser,svc192,company_description,app.TARGETSYSTEM_DEBUG,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27884,rparser,svc192,company_description,app.TARGETSYSTEM_STR,NAME,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27885,rparser,svc192,company_description,app.INSERTBIZLOGSQL,false,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27886,rparser,svc192,company_description,app.EXCLUDEPATTERN,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27887,rparser,svc192,company_description,app.USERINFOBYIP,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27888,rparser,svc192,company_description,app.NOUSERINFONOCOLLECT,false,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27889,rparser,svc192,company_description,app.LOGRESULTLEVEL,ALL,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27890,rparser,svc192,company_description,app.EXCLUDEPATTERN3,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27891,rparser,svc192,company_description,app.MIPLATFORM_USE,false,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27892,rparser,svc192,company_description,app.MIPLATFORM_SYSTEM,"02",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27893,rparser,svc192,company_description,app.FIND_QUERY,"08_%US_loginId:_%US_",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27894,rparser,svc192,company_description,app.PRIVTYPE_AND_GROUP,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27895,rparser,svc192,company_description,app.MERGE_LIMIT_SYSTEM,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27896,rparser,svc192,company_description,app.MERGE_LIMIT_SEC,-60,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27897,rparser,svc192,company_description,app.CHECK_SCHEMA,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27898,rparser,svc192,company_description,app.MENU_IN_REFERER_SYSTEM,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27899,rparser,svc192,company_description,app.SAVE_REQ_RES_DATA,"0",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27900,rparser,svc192,company_description,app.FORCE_USER_ACT_FINDER,"0",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27901,rparser,svc192,company_description,app.FIND_USER_ACT_IN_REQ,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27902,rparser,svc192,company_description,app.FIND_USER_ACT_IN_RES,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27903,rparser,svc192,company_description,app.EXTRACT_PRIV_INFO_BY_REQ_RES,"0",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27904,rparser,svc192,company_description,app.EXTRACT_PRIV_INFO_BY_URL,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27905,rparser,svc192,company_description,app.EXTRACT_PRIV_INFO_BY_REQ_BODY,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27906,rparser,svc192,company_description,app.EXTRACT_PRIV_INFO_BY_RES_BODY,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27908,rparser,svc192,company_description,app.SYSTEM_CODE_BY_URL_06,"P7:07,P8:07,P9:07,P10:07,P13:07",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27909,rparser,svc192,company_description,app.SYSTEM_CODE_BY_URL_USE_REFERRER_06,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27910,rparser,svc192,company_description,app.T_TAG_02,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27911,rparser,svc192,company_description,app.T_TAG_03,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27912,rparser,svc192,company_description,app.T_TAG_04,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27913,rparser,svc192,company_description,app.T_TAG_05,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27914,rparser,svc192,company_description,app.T_TAG_06,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27915,rparser,svc192,company_description,app.T_TAG_07,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27916,rparser,svc192,company_description,app.ONLY_REQ_TYPE_RD,use,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27917,rparser,svc192,company_description,app.INSERT_REQSP_BODY,"2",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27918,rparser,svc192,company_description,app.INSERT_REQSP_BODY_ONLYURL,"1",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27919,rparser,svc192,company_description,app.FORCE_REF_LOG,use,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27920,rparser,svc192,company_description,app.FULLSCAN_ENGINE,use,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27921,rparser,svc192,company_description,app.path.attachedfile,/usr/local/PSM/logs/downloadfile,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27922,rparser,svc192,company_description,app.EXCLUDE_FILE_EXT,(.*png|.*bmp|.*gif|.*PNG|.*BMP|.*GIF),2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27923,rparser,svc192,company_description,app.IS_ATTACHED_FILE_LEAVE,false,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27924,rparser,svc192,company_description,app.DN_LOG_TO_DN_TABLE,use,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27925,rparser,svc192,company_description,app.REPLACE_ID,SSO_SAEOL_,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27926,rparser,svc192,company_description,app.REMOVE_URL_PARAM,use,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27927,rparser,svc192,company_description,app.MIPLATFORM_REASM_GS,_%GS_,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27928,rparser,svc192,company_description,app.MIPLATFORM_REASM_US,_%US_,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27929,rparser,svc192,company_description,app.MIPLATFORM_REASM_PI_END,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27930,rparser,svc192,company_description,app.MIPLATFORM_REASM_VARIABLES,tnoDiv04_%US_tnoFront04_%US_tnoTail04,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27931,rparser,svc192,company_description,app.MIPLATFORM_REASM_PI_SEPARATOR,-_%US_-,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27932,rparser,svc192,company_description,app.KOSAF_FIND_QUERY_SCRNID,"03_%US_<gScrnId>_%US_</gScrnId>",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27933,rparser,svc192,company_description,app.KOSAF_FIND_QUERY_SCRNNM,"03_%US_<gScrnNm>_%US_</gScrnNm>",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27934,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT,false,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27935,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_1,\uC8FC\uBBFC\uB4F1\uB85D\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27936,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_2,\uC6B4\uC804\uBA74\uD5C8\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27937,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_3,\uC5EC\uAD8C\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27938,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_4,\uC2E0\uC6A9\uCE74\uB4DC\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27939,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_5,\uAC74\uAC15\uBCF4\uD5D8\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27940,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_6,\uC804\uD654\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27941,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_7,\uC774\uBA54\uC77C,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27942,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_8,\uD734\uB300\uD3F0\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27943,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_9,\uACC4\uC88C\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27944,rparser,svc192,company_description,app.MASKING_BEFORE_INSERT_10,\uC678\uAD6D\uC778\uB4F1\uB85D\uBC88\uD638,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27945,rparser,svc192,company_description,app.EMP_ID_UPPER,"",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27946,rparser,svc192,company_description,app.INSERTBIZLOGSQL_TYPE2,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27947,rparser,svc192,company_description,app.COLLECT_FROM_SQL_RESULT,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27948,rparser,svc192,company_description,app.INITPATH,/app/damo/scpdb_agent_unix.ini,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27949,rparser,svc192,company_description,app.NHFIRE_DEVON_03,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27950,rparser,svc192,company_description,app.NHFIRE_DEVON_23,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27951,rparser,svc192,company_description,app.SYSTEM_CODE_BY_URL_05,smartapp:08,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27952,rparser,svc192,company_description,app.SYSTEM_CODE_BY_URL_25,smartapp:28,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27953,rparser,svc192,company_description,app.INCLUDE_FILE_EXT,(.*xls|.*xlsx),2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27954,rparser,svc192,company_description,app.NHFIRE_OPTION_TYPE_001_03,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27955,rparser,svc192,company_description,app.NHFIRE_OPTION_TYPE_001_23,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27956,rparser,svc192,company_description,app.LOCAL_DEV,true,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27957,rparser,svc192,company_description,app.MQ_EXCHANGE,psm-svc192-exchange,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27958,rparser,svc192,company_description,app.MQ_QUEUE_NAME,psm-svc192-queue,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27959,rparser,svc192,company_description,app.MQ_ROUTING_KEY,psm-svc192-routing-key,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27960,rparser,svc192,company_description,app.MQ_HOST,simple-rabbit-mq-1-6quq9.kr.vrmq-gov.naverncp.com,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27971,rparser,svc192,company_description,app.MQ_PORT,"5672",2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
27999,rparser,svc192,company_description,app.schema,psm_sc_svc192,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
28028,rparser,svc192,company_description,spring.datasource.url,jdbc:postgresql://pg-1f3ar.vpc-cdb-kr.gov-ntruss.com:5432/psm_1?charSet=ko_KR.UTF8&currentSchema=psm_sc_svc192,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
28030,rparser,svc192,company_description,spring.datasource.username,psm_user,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
28031,rparser,svc192,company_description,spring.datasource.password,dlwltjxl2@,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
28053,rparser,svc192,company_description,app.MQ_USER,psm-saas,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
28054,rparser,svc192,company_description,app.MQ_PASSWD,dlwltjxl1!,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
28137,rparser,svc192,company_description,app.TRUST_PASSWORD,easyceri1,2023-10-06 13:19:40.345,2023-10-06 13:19:40.345,
'''

# %%
temp = [ ': '.join(line.split(',')[4:6]) for line in application_yml.split('\n')[2:-1] ]
temp.sort()
print('\n'.join(temp))
# Out:
# app.CHECK_SCHEMA: "1"
# app.COLLECT_FROM_SQL_RESULT: true
# app.DN_LOG_TO_DN_TABLE: use
# app.EMP_ID_UPPER: ""
# app.EXCLUDEPATTERN3: ""
# app.EXCLUDEPATTERN: ""
# app.EXCLUDE_FILE_EXT: (.*png|.*bmp|.*gif|.*PNG|.*BMP|.*GIF)
# app.EXTRACT_PRIV_INFO_BY_REQ_BODY: "1"
# app.EXTRACT_PRIV_INFO_BY_REQ_RES: "0"
# app.EXTRACT_PRIV_INFO_BY_RES_BODY: "1"
# app.EXTRACT_PRIV_INFO_BY_URL: "1"
# app.FAILPATH:  /usr/local/PSM/logs/ResponseLog/fail/
# app.FILEDELETEOPTION: "1"
# app.FILEINPATH: /usr/local/PSM/logs/ResponseLog/in/
# app.FILENAME: EZ_PRIV_LOG
# app.FILEOUTPATH: /usr/local/PSM/logs/ResponseLog/out/
# app.FILEWORKPATH: /usr/local/PSM/logs/ResponseLog/work/
# app.FIND_QUERY: "08_%US_loginId:_%US_"
# app.FIND_USER_ACT_IN_REQ: ""
# app.FIND_USER_ACT_IN_RES: ""
# app.FORCE_REF_LOG: use
# app.FORCE_USER_ACT_FINDER: "0"
# app.FULLSCAN_ENGINE: use
# app.INCLUDE_FILE_EXT: (.*xls|.*xlsx)
# app.INITPATH: /app/damo/scpdb_agent_unix.ini
# app.INSERTBIZLOGSQL: false
# app.INSERTBIZLOGSQL_TYPE2: true
# ...

# %%
# "select \r\n  name, setting, source, sourcefile, sourceline \r\nfrom \r\n  pg_settings\r\norder by source": 
postgres_config = \
'''{
"config": [
	{
		"name" : "client_encoding",
		"setting" : "UTF8",
		"source" : "client"
	},
	{
		"name" : "DateStyle",
		"setting" : "ISO, MDY",
		"source" : "client"
	},
	{
		"name" : "TimeZone",
		"setting" : "Asia\/Seoul",
		"source" : "client"
	},
	{
		"name" : "listen_addresses",
		"setting" : "*",
		"source" : "command line"
	},
	{
		"name" : "port",
		"setting" : "5432",
		"source" : "command line"
	},
	{
		"name" : "wal_sender_timeout",
		"setting" : "30000",
		"source" : "configuration file"
	},
	{
		"name" : "default_text_search_config",
		"setting" : "pg_catalog.english",
		"source" : "configuration file"
	},
	{
		"name" : "random_page_cost",
		"setting" : "1.1",
		"source" : "configuration file"
	},
	{
		"name" : "archive_timeout",
		"setting" : "0",
		"source" : "configuration file"
	},
	{
		"name" : "wal_log_hints",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "log_timezone",
		"setting" : "Asia\/Seoul",
		"source" : "configuration file"
	},
	{
		"name" : "wal_keep_size",
		"setting" : "8192",
		"source" : "configuration file"
	},
	{
		"name" : "wal_compression",
		"setting" : "off",
		"source" : "configuration file"
	},
	{
		"name" : "logging_collector",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "default_transaction_read_only",
		"setting" : "off",
		"source" : "configuration file"
	},
	{
		"name" : "recovery_target_timeline",
		"setting" : "latest",
		"source" : "configuration file"
	},
	{
		"name" : "maintenance_work_mem",
		"setting" : "418816",
		"source" : "configuration file"
	},
	{
		"name" : "max_connections",
		"setting" : "819",
		"source" : "configuration file"
	},
	{
		"name" : "effective_cache_size",
		"setting" : "524288",
		"source" : "configuration file"
	},
	{
		"name" : "hot_standby",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "track_functions",
		"setting" : "pl",
		"source" : "configuration file"
	},
	{
		"name" : "hot_standby_feedback",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "track_commit_timestamp",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "effective_io_concurrency",
		"setting" : "200",
		"source" : "configuration file"
	},
	{
		"name" : "idle_in_transaction_session_timeout",
		"setting" : "86400000",
		"source" : "configuration file"
	},
	{
		"name" : "log_autovacuum_min_duration",
		"setting" : "10000",
		"source" : "configuration file"
	},
	{
		"name" : "shared_buffers",
		"setting" : "262144",
		"source" : "configuration file"
	},
	{
		"name" : "max_parallel_workers",
		"setting" : "8",
		"source" : "configuration file"
	},
	{
		"name" : "ssl",
		"setting" : "off",
		"source" : "configuration file"
	},
	{
		"name" : "max_parallel_workers_per_gather",
		"setting" : "2",
		"source" : "configuration file"
	},
	{
		"name" : "log_checkpoints",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "log_connections",
		"setting" : "off",
		"source" : "configuration file"
	},
	{
		"name" : "log_destination",
		"setting" : "stderr",
		"source" : "configuration file"
	},
	{
		"name" : "log_disconnections",
		"setting" : "off",
		"source" : "configuration file"
	},
	{
		"name" : "max_replication_slots",
		"setting" : "20",
		"source" : "configuration file"
	},
	{
		"name" : "wal_buffers",
		"setting" : "2048",
		"source" : "configuration file"
	},
	{
		"name" : "autovacuum_vacuum_scale_factor",
		"setting" : "0.08",
		"source" : "configuration file"
	},
	{
		"name" : "work_mem",
		"setting" : "4096",
		"source" : "configuration file"
	},
	{
		"name" : "log_file_mode",
		"setting" : "0644",
		"source" : "configuration file"
	},
	{
		"name" : "synchronous_commit",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "synchronous_standby_names",
		"setting" : "ANY 1 (pgautofailover_standby_1376)",
		"source" : "configuration file"
	},
	{
		"name" : "max_wal_senders",
		"setting" : "20",
		"source" : "configuration file"
	},
	{
		"name" : "max_wal_size",
		"setting" : "8192",
		"source" : "configuration file"
	},
	{
		"name" : "max_worker_processes",
		"setting" : "8",
		"source" : "configuration file"
	},
	{
		"name" : "wal_level",
		"setting" : "logical",
		"source" : "configuration file"
	},
	{
		"name" : "log_line_prefix",
		"setting" : "[%t]-%p %q-%u@%r:%d-%a ",
		"source" : "configuration file"
	},
	{
		"name" : "min_wal_size",
		"setting" : "2048",
		"source" : "configuration file"
	},
	{
		"name" : "log_lock_waits",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "autovacuum_max_workers",
		"setting" : "3",
		"source" : "configuration file"
	},
	{
		"name" : "jit",
		"setting" : "off",
		"source" : "configuration file"
	},
	{
		"name" : "archive_command",
		"setting" : "pigz -4 -p 4 < %p > \/mnt\/nas\/601\/psm-saas-001-p1i\/pgarchive\/%f.gz && chmod 660 \/mnt\/nas\/601\/psm-saas-001-p1i\/pgarchive\/%f.gz",
		"source" : "configuration file"
	},
	{
		"name" : "log_min_messages",
		"setting" : "info",
		"source" : "configuration file"
	},
	{
		"name" : "password_encryption",
		"setting" : "scram-sha-256",
		"source" : "configuration file"
	},
	{
		"name" : "pg_stat_statements.max",
		"setting" : "5000",
		"source" : "configuration file"
	},
	{
		"name" : "autovacuum_naptime",
		"setting" : "15",
		"source" : "configuration file"
	},
	{
		"name" : "pg_stat_statements.track",
		"setting" : "top",
		"source" : "configuration file"
	},
	{
		"name" : "archive_mode",
		"setting" : "on",
		"source" : "configuration file"
	},
	{
		"name" : "checkpoint_completion_target",
		"setting" : "0.9",
		"source" : "configuration file"
	},
	{
		"name" : "track_activity_query_size",
		"setting" : "8192",
		"source" : "configuration file"
	},
	{
		"name" : "autovacuum_vacuum_cost_limit",
		"setting" : "200",
		"source" : "configuration file"
	},
	{
		"name" : "autovacuum_analyze_scale_factor",
		"setting" : "0.05",
		"source" : "configuration file"
	},
	{
		"name" : "log_rotation_age",
		"setting" : "1440",
		"source" : "configuration file"
	},
	{
		"name" : "log_rotation_size",
		"setting" : "10240",
		"source" : "configuration file"
	},
	{
		"name" : "enable_partition_pruning",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_partitionwise_aggregate",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "enable_partitionwise_join",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "enable_seqscan",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_sort",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_tidscan",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "escape_string_warning",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "event_source",
		"setting" : "PostgreSQL",
		"source" : "default"
	},
	{
		"name" : "exit_on_error",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "force_parallel_mode",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "from_collapse_limit",
		"setting" : "8",
		"source" : "default"
	},
	{
		"name" : "fsync",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "full_page_writes",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "geqo",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "geqo_effort",
		"setting" : "5",
		"source" : "default"
	},
	{
		"name" : "geqo_generations",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "geqo_pool_size",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "geqo_seed",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "geqo_selection_bias",
		"setting" : "2",
		"source" : "default"
	},
	{
		"name" : "geqo_threshold",
		"setting" : "12",
		"source" : "default"
	},
	{
		"name" : "gin_fuzzy_search_limit",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "gin_pending_list_limit",
		"setting" : "4096",
		"source" : "default"
	},
	{
		"name" : "hash_mem_multiplier",
		"setting" : "1",
		"source" : "default"
	},
	{
		"name" : "huge_pages",
		"setting" : "try",
		"source" : "default"
	},
	{
		"name" : "ignore_checksum_failure",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "ignore_invalid_pages",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "ignore_system_indexes",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "integer_datetimes",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "IntervalStyle",
		"setting" : "postgres",
		"source" : "default"
	},
	{
		"name" : "jit_above_cost",
		"setting" : "100000",
		"source" : "default"
	},
	{
		"name" : "jit_debugging_support",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "jit_dump_bitcode",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "jit_expressions",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "jit_inline_above_cost",
		"setting" : "500000",
		"source" : "default"
	},
	{
		"name" : "jit_optimize_above_cost",
		"setting" : "500000",
		"source" : "default"
	},
	{
		"name" : "jit_profiling_support",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "jit_tuple_deforming",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "join_collapse_limit",
		"setting" : "8",
		"source" : "default"
	},
	{
		"name" : "krb_caseins_users",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "lc_messages",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "lc_monetary",
		"setting" : "C",
		"source" : "default"
	},
	{
		"name" : "lc_numeric",
		"setting" : "C",
		"source" : "default"
	},
	{
		"name" : "lc_time",
		"setting" : "C",
		"source" : "default"
	},
	{
		"name" : "lo_compat_privileges",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "local_preload_libraries",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "lock_timeout",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "log_duration",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_error_verbosity",
		"setting" : "default",
		"source" : "default"
	},
	{
		"name" : "log_executor_stats",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_hostname",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_min_duration_sample",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "log_min_duration_statement",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "log_min_error_statement",
		"setting" : "error",
		"source" : "default"
	},
	{
		"name" : "log_parameter_max_length",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "log_parameter_max_length_on_error",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "log_parser_stats",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_planner_stats",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_replication_commands",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_statement",
		"setting" : "none",
		"source" : "default"
	},
	{
		"name" : "log_statement_sample_rate",
		"setting" : "1",
		"source" : "default"
	},
	{
		"name" : "log_statement_stats",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "log_temp_files",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "log_transaction_sample_rate",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "log_truncate_on_rotation",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "logical_decoding_work_mem",
		"setting" : "65536",
		"source" : "default"
	},
	{
		"name" : "maintenance_io_concurrency",
		"setting" : "10",
		"source" : "default"
	},
	{
		"name" : "max_files_per_process",
		"setting" : "1000",
		"source" : "default"
	},
	{
		"name" : "max_function_args",
		"setting" : "100",
		"source" : "default"
	},
	{
		"name" : "max_identifier_length",
		"setting" : "63",
		"source" : "default"
	},
	{
		"name" : "max_index_keys",
		"setting" : "32",
		"source" : "default"
	},
	{
		"name" : "max_locks_per_transaction",
		"setting" : "64",
		"source" : "default"
	},
	{
		"name" : "max_logical_replication_workers",
		"setting" : "4",
		"source" : "default"
	},
	{
		"name" : "max_parallel_maintenance_workers",
		"setting" : "2",
		"source" : "default"
	},
	{
		"name" : "max_pred_locks_per_page",
		"setting" : "2",
		"source" : "default"
	},
	{
		"name" : "max_pred_locks_per_relation",
		"setting" : "-2",
		"source" : "default"
	},
	{
		"name" : "max_pred_locks_per_transaction",
		"setting" : "64",
		"source" : "default"
	},
	{
		"name" : "max_prepared_transactions",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "max_slot_wal_keep_size",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "max_standby_archive_delay",
		"setting" : "30000",
		"source" : "default"
	},
	{
		"name" : "max_standby_streaming_delay",
		"setting" : "30000",
		"source" : "default"
	},
	{
		"name" : "max_sync_workers_per_subscription",
		"setting" : "2",
		"source" : "default"
	},
	{
		"name" : "min_parallel_index_scan_size",
		"setting" : "64",
		"source" : "default"
	},
	{
		"name" : "min_parallel_table_scan_size",
		"setting" : "1024",
		"source" : "default"
	},
	{
		"name" : "old_snapshot_threshold",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "operator_precedence_warning",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "parallel_leader_participation",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "parallel_setup_cost",
		"setting" : "1000",
		"source" : "default"
	},
	{
		"name" : "parallel_tuple_cost",
		"setting" : "0.1",
		"source" : "default"
	},
	{
		"name" : "pg_stat_statements.save",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "pg_stat_statements.track_planning",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "pg_stat_statements.track_utility",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "plan_cache_mode",
		"setting" : "auto",
		"source" : "default"
	},
	{
		"name" : "post_auth_delay",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "pre_auth_delay",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "primary_slot_name",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "promote_trigger_file",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "quote_all_identifiers",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "recovery_end_command",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "recovery_min_apply_delay",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "recovery_target",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "recovery_target_action",
		"setting" : "pause",
		"source" : "default"
	},
	{
		"name" : "recovery_target_inclusive",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "recovery_target_lsn",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "recovery_target_name",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "recovery_target_time",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "recovery_target_xid",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "restart_after_crash",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "restore_command",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "row_security",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "segment_size",
		"setting" : "131072",
		"source" : "default"
	},
	{
		"name" : "seq_page_cost",
		"setting" : "1",
		"source" : "default"
	},
	{
		"name" : "server_version",
		"setting" : "13.7",
		"source" : "default"
	},
	{
		"name" : "server_version_num",
		"setting" : "130007",
		"source" : "default"
	},
	{
		"name" : "session_replication_role",
		"setting" : "origin",
		"source" : "default"
	},
	{
		"name" : "shared_memory_type",
		"setting" : "mmap",
		"source" : "default"
	},
	{
		"name" : "ssl_ca_file",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "ssl_cert_file",
		"setting" : "server.crt",
		"source" : "default"
	},
	{
		"name" : "ssl_crl_file",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "ssl_key_file",
		"setting" : "server.key",
		"source" : "default"
	},
	{
		"name" : "ssl_library",
		"setting" : "OpenSSL",
		"source" : "default"
	},
	{
		"name" : "ssl_passphrase_command_supports_reload",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "ssl_prefer_server_ciphers",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "standard_conforming_strings",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "statement_timeout",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "superuser_reserved_connections",
		"setting" : "3",
		"source" : "default"
	},
	{
		"name" : "synchronize_seqscans",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "syslog_facility",
		"setting" : "local0",
		"source" : "default"
	},
	{
		"name" : "syslog_ident",
		"setting" : "postgres",
		"source" : "default"
	},
	{
		"name" : "syslog_sequence_numbers",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "syslog_split_messages",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "tcp_keepalives_count",
		"setting" : "9",
		"source" : "default"
	},
	{
		"name" : "tcp_keepalives_idle",
		"setting" : "7200",
		"source" : "default"
	},
	{
		"name" : "tcp_keepalives_interval",
		"setting" : "75",
		"source" : "default"
	},
	{
		"name" : "tcp_user_timeout",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "temp_buffers",
		"setting" : "1024",
		"source" : "default"
	},
	{
		"name" : "temp_file_limit",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "temp_tablespaces",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "timezone_abbreviations",
		"setting" : "Default",
		"source" : "default"
	},
	{
		"name" : "trace_notify",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "trace_recovery_messages",
		"setting" : "log",
		"source" : "default"
	},
	{
		"name" : "trace_sort",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "track_activities",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "zero_damaged_pages",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "archive_cleanup_command",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "array_nulls",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "authentication_timeout",
		"setting" : "60",
		"source" : "default"
	},
	{
		"name" : "autovacuum",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "autovacuum_analyze_threshold",
		"setting" : "50",
		"source" : "default"
	},
	{
		"name" : "autovacuum_freeze_max_age",
		"setting" : "200000000",
		"source" : "default"
	},
	{
		"name" : "autovacuum_multixact_freeze_max_age",
		"setting" : "400000000",
		"source" : "default"
	},
	{
		"name" : "autovacuum_vacuum_cost_delay",
		"setting" : "2",
		"source" : "default"
	},
	{
		"name" : "autovacuum_vacuum_insert_scale_factor",
		"setting" : "0.2",
		"source" : "default"
	},
	{
		"name" : "autovacuum_vacuum_insert_threshold",
		"setting" : "1000",
		"source" : "default"
	},
	{
		"name" : "autovacuum_vacuum_threshold",
		"setting" : "50",
		"source" : "default"
	},
	{
		"name" : "autovacuum_work_mem",
		"setting" : "-1",
		"source" : "default"
	},
	{
		"name" : "backend_flush_after",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "backslash_quote",
		"setting" : "safe_encoding",
		"source" : "default"
	},
	{
		"name" : "backtrace_functions",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "bgwriter_delay",
		"setting" : "200",
		"source" : "default"
	},
	{
		"name" : "bgwriter_flush_after",
		"setting" : "64",
		"source" : "default"
	},
	{
		"name" : "bgwriter_lru_maxpages",
		"setting" : "100",
		"source" : "default"
	},
	{
		"name" : "bgwriter_lru_multiplier",
		"setting" : "2",
		"source" : "default"
	},
	{
		"name" : "block_size",
		"setting" : "8192",
		"source" : "default"
	},
	{
		"name" : "bonjour",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "bonjour_name",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "bytea_output",
		"setting" : "hex",
		"source" : "default"
	},
	{
		"name" : "check_function_bodies",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "checkpoint_flush_after",
		"setting" : "32",
		"source" : "default"
	},
	{
		"name" : "checkpoint_timeout",
		"setting" : "300",
		"source" : "default"
	},
	{
		"name" : "checkpoint_warning",
		"setting" : "30",
		"source" : "default"
	},
	{
		"name" : "client_min_messages",
		"setting" : "notice",
		"source" : "default"
	},
	{
		"name" : "cluster_name",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "commit_delay",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "commit_siblings",
		"setting" : "5",
		"source" : "default"
	},
	{
		"name" : "constraint_exclusion",
		"setting" : "partition",
		"source" : "default"
	},
	{
		"name" : "cpu_index_tuple_cost",
		"setting" : "0.005",
		"source" : "default"
	},
	{
		"name" : "cpu_operator_cost",
		"setting" : "0.0025",
		"source" : "default"
	},
	{
		"name" : "cpu_tuple_cost",
		"setting" : "0.01",
		"source" : "default"
	},
	{
		"name" : "cursor_tuple_fraction",
		"setting" : "0.1",
		"source" : "default"
	},
	{
		"name" : "data_directory_mode",
		"setting" : "0700",
		"source" : "default"
	},
	{
		"name" : "data_sync_retry",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "db_user_namespace",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "deadlock_timeout",
		"setting" : "1000",
		"source" : "default"
	},
	{
		"name" : "debug_assertions",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "debug_pretty_print",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "debug_print_parse",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "debug_print_plan",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "debug_print_rewritten",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "default_statistics_target",
		"setting" : "100",
		"source" : "default"
	},
	{
		"name" : "default_table_access_method",
		"setting" : "heap",
		"source" : "default"
	},
	{
		"name" : "default_tablespace",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "default_transaction_deferrable",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "dynamic_shared_memory_type",
		"setting" : "posix",
		"source" : "default"
	},
	{
		"name" : "enable_bitmapscan",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_gathermerge",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_hashagg",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_hashjoin",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_incremental_sort",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_indexonlyscan",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_indexscan",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_material",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_mergejoin",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_nestloop",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_parallel_append",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "enable_parallel_hash",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "wal_init_zero",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "wal_receiver_create_temp_slot",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "wal_receiver_status_interval",
		"setting" : "10",
		"source" : "default"
	},
	{
		"name" : "wal_receiver_timeout",
		"setting" : "60000",
		"source" : "default"
	},
	{
		"name" : "wal_recycle",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "wal_retrieve_retry_interval",
		"setting" : "5000",
		"source" : "default"
	},
	{
		"name" : "wal_skip_threshold",
		"setting" : "2048",
		"source" : "default"
	},
	{
		"name" : "wal_sync_method",
		"setting" : "fdatasync",
		"source" : "default"
	},
	{
		"name" : "wal_writer_delay",
		"setting" : "200",
		"source" : "default"
	},
	{
		"name" : "wal_writer_flush_after",
		"setting" : "128",
		"source" : "default"
	},
	{
		"name" : "xmlbinary",
		"setting" : "base64",
		"source" : "default"
	},
	{
		"name" : "xmloption",
		"setting" : "content",
		"source" : "default"
	},
	{
		"name" : "allow_system_table_mods",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "track_counts",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "track_io_timing",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "transform_null_equals",
		"setting" : "off",
		"source" : "default"
	},
	{
		"name" : "unix_socket_group",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "unix_socket_permissions",
		"setting" : "0777",
		"source" : "default"
	},
	{
		"name" : "update_process_title",
		"setting" : "on",
		"source" : "default"
	},
	{
		"name" : "vacuum_cleanup_index_scale_factor",
		"setting" : "0.1",
		"source" : "default"
	},
	{
		"name" : "vacuum_cost_delay",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "vacuum_cost_limit",
		"setting" : "200",
		"source" : "default"
	},
	{
		"name" : "vacuum_cost_page_dirty",
		"setting" : "20",
		"source" : "default"
	},
	{
		"name" : "vacuum_cost_page_hit",
		"setting" : "1",
		"source" : "default"
	},
	{
		"name" : "vacuum_cost_page_miss",
		"setting" : "10",
		"source" : "default"
	},
	{
		"name" : "vacuum_defer_cleanup_age",
		"setting" : "0",
		"source" : "default"
	},
	{
		"name" : "vacuum_freeze_min_age",
		"setting" : "50000000",
		"source" : "default"
	},
	{
		"name" : "vacuum_freeze_table_age",
		"setting" : "150000000",
		"source" : "default"
	},
	{
		"name" : "vacuum_multixact_freeze_min_age",
		"setting" : "5000000",
		"source" : "default"
	},
	{
		"name" : "vacuum_multixact_freeze_table_age",
		"setting" : "150000000",
		"source" : "default"
	},
	{
		"name" : "wal_block_size",
		"setting" : "8192",
		"source" : "default"
	},
	{
		"name" : "wal_consistency_checking",
		"setting" : "",
		"source" : "default"
	},
	{
		"name" : "max_stack_depth",
		"setting" : "2048",
		"source" : "environment variable"
	},
	{
		"name" : "server_encoding",
		"setting" : "UTF8",
		"source" : "override"
	},
	{
		"name" : "transaction_read_only",
		"setting" : "off",
		"source" : "override"
	},
	{
		"name" : "lc_ctype",
		"setting" : "C",
		"source" : "override"
	},
	{
		"name" : "wal_segment_size",
		"setting" : "1073741824",
		"source" : "override"
	},
	{
		"name" : "lc_collate",
		"setting" : "C",
		"source" : "override"
	},
	{
		"name" : "data_checksums",
		"setting" : "on",
		"source" : "override"
	},
	{
		"name" : "transaction_deferrable",
		"setting" : "off",
		"source" : "override"
	},
	{
		"name" : "transaction_isolation",
		"setting" : "read committed",
		"source" : "override"
	},
	{
		"name" : "search_path",
		"setting" : "psm_schema, psm_schema, portal_schema",
		"source" : "session"
	},
	{
		"name" : "application_name",
		"setting" : "DBeaver 23.1.3 - SQLEditor <Script.sql>",
		"source" : "session"
	},
	{
		"name" : "default_transaction_isolation",
		"setting" : "read committed",
		"source" : "session"
	},
	{
		"name" : "extra_float_digits",
		"setting" : "3",
		"source" : "session"
	}
]}
'''

# %%
import json
json.loads( postgres_config )['config']

# %%
# !python -m pip install xlsxwriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 5.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from xlsxwriter import Workbook

xlsx_dir = './postgres.xlsx'

df = pd.DataFrame(
    json.loads( postgres_config )['config']
)

df.to_excel(
    xlsx_dir, # directory and file name to write
    sheet_name = 'Sheet1', 
    na_rep = 'NaN', 
    # float_format = "%.2f", 
    header = True, 
    columns = df.columns,
    #columns = ["group", "value_1", "value_2"], # if header is False
    index = True, 
    index_label = "no", 
    startrow = 2, 
    startcol = 1, 
    engine = 'xlsxwriter', 
    # freeze_panes = (2, 0)
)

# %%
text = \
'''Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Autovacuum
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Locale and Formatting
Client Connection Defaults / Other Defaults
Client Connection Defaults / Other Defaults
Client Connection Defaults / Other Defaults
Client Connection Defaults / Other Defaults
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Client Connection Defaults / Statement Behavior
Connections and Authentication / Authentication
Connections and Authentication / Authentication
Connections and Authentication / Connection Settings
Connections and Authentication / Connection Settings
Connections and Authentication / Connection Settings
Connections and Authentication / Connection Settings
Connections and Authentication / Connection Settings
Customized Options
Customized Options
Customized Options
Customized Options
Customized Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Developer Options
Error Handling
Lock Management
Lock Management
Lock Management
Lock Management
Lock Management
Preset Options
Preset Options
Preset Options
Preset Options
Preset Options
Preset Options
Preset Options
Preset Options
Preset Options
Preset Options
Process Title
Query Tuning / Genetic Query Optimizer
Query Tuning / Genetic Query Optimizer
Query Tuning / Genetic Query Optimizer
Query Tuning / Genetic Query Optimizer
Query Tuning / Genetic Query Optimizer
Query Tuning / Genetic Query Optimizer
Query Tuning / Genetic Query Optimizer
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Other Planner Options
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Cost Constants
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Query Tuning / Planner Method Configuration
Replication
Replication / Master Server
Replication / Sending Servers
Replication / Sending Servers
Replication / Sending Servers
Replication / Sending Servers
Replication / Sending Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Standby Servers
Replication / Subscribers
Replication / Subscribers
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / What to Log
Reporting and Logging / When to Log
Reporting and Logging / When to Log
Reporting and Logging / When to Log
Reporting and Logging / When to Log
Reporting and Logging / When to Log
Reporting and Logging / When to Log
Reporting and Logging / Where to Log
Reporting and Logging / Where to Log
Reporting and Logging / Where to Log
Reporting and Logging / Where to Log
Reporting and Logging / Where to Log
Reporting and Logging / Where to Log
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Asynchronous Behavior
Resource Usage / Background Writer
Resource Usage / Background Writer
Resource Usage / Background Writer
Resource Usage / Background Writer
Resource Usage / Cost-Based Vacuum Delay
Resource Usage / Cost-Based Vacuum Delay
Resource Usage / Cost-Based Vacuum Delay
Resource Usage / Cost-Based Vacuum Delay
Resource Usage / Cost-Based Vacuum Delay
Resource Usage / Disk
Resource Usage / Kernel Resources
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Resource Usage / Memory
Statistics / Monitoring
Statistics / Monitoring
Statistics / Monitoring
Statistics / Monitoring
Statistics / Query and Index Statistics Collector
Statistics / Query and Index Statistics Collector
Version and Platform Compatibility / Other Platforms and Clients
Version and Platform Compatibility / Previous PostgreSQL Versions
Version and Platform Compatibility / Previous PostgreSQL Versions
Version and Platform Compatibility / Previous PostgreSQL Versions
Version and Platform Compatibility / Previous PostgreSQL Versions
Version and Platform Compatibility / Previous PostgreSQL Versions
Version and Platform Compatibility / Previous PostgreSQL Versions
Version and Platform Compatibility / Previous PostgreSQL Versions
Write-Ahead Log / Archiving
Write-Ahead Log / Archiving
Write-Ahead Log / Checkpoints
Write-Ahead Log / Checkpoints
Write-Ahead Log / Checkpoints
Write-Ahead Log / Checkpoints
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings
Write-Ahead Log / Settings'''

# %%
print( *sorted(list(set(text.split('\n')))), sep='\n')
# Out:
# Autovacuum
# Client Connection Defaults / Locale and Formatting
# Client Connection Defaults / Other Defaults
# Client Connection Defaults / Statement Behavior
# Connections and Authentication / Authentication
# Connections and Authentication / Connection Settings
# Customized Options
# Developer Options
# Error Handling
# Lock Management
# Preset Options
# Process Title
# Query Tuning / Genetic Query Optimizer
# Query Tuning / Other Planner Options
# Query Tuning / Planner Cost Constants
# Query Tuning / Planner Method Configuration
# Replication
# Replication / Master Server
# Replication / Sending Servers
# Replication / Standby Servers
# Replication / Subscribers
# Reporting and Logging / What to Log
# Reporting and Logging / When to Log
# Reporting and Logging / Where to Log
# Resource Usage / Asynchronous Behavior
# Resource Usage / Background Writer
# Resource Usage / Cost-Based Vacuum Delay
# Resource Usage / Disk
# Resource Usage / Kernel Resources
# Resource Usage / Memory
# ...

# %%
text = \
'''String CHARSET_NAME = "UTF-8";
String HMAC_ALGORITHM = "HmacSHA256";
String HASH_ALGORITHM = "SHA-256";
String AWS_ALGORITHM = "AWS4-HMAC-SHA256";

String SERVICE_NAME = "s3";
String REQUEST_TYPE = "aws4_request";

String UNSIGNED_PAYLOAD = "UNSIGNED-PAYLOAD";
String REGION_NAME = "gov-standard";
String ENDPOINT_SEOUL = "https://kr.object.gov-ncloudstorage.com";
String ENDPOINT_SOUTH = "https://krs.object.gov-ncloudstorage.com";
String ACCESS_KEY = "LU2uVIWLmbQuI7ngYqnv";
String SECRET_KEY = "KjYrWWKoybZZXlycnlL8Vm9fCZ3VZqTQfnbSneYn";'''

# %%
text.split("\n")

for line in text.split("\n"):
    if len(line) < 1:
        continue
    env = line.split(' ')[1]
    print(f'.append("{env:15s} : ").append("ENC(").append( jasyptEncoding({env}) ).append(")<br />")')
# Out:
# .append("CHARSET_NAME    : ").append("ENC(").append( jasyptEncoding(CHARSET_NAME) ).append(")<br />")
# .append("HMAC_ALGORITHM  : ").append("ENC(").append( jasyptEncoding(HMAC_ALGORITHM) ).append(")<br />")
# .append("HASH_ALGORITHM  : ").append("ENC(").append( jasyptEncoding(HASH_ALGORITHM) ).append(")<br />")
# .append("AWS_ALGORITHM   : ").append("ENC(").append( jasyptEncoding(AWS_ALGORITHM) ).append(")<br />")
# .append("SERVICE_NAME    : ").append("ENC(").append( jasyptEncoding(SERVICE_NAME) ).append(")<br />")
# .append("REQUEST_TYPE    : ").append("ENC(").append( jasyptEncoding(REQUEST_TYPE) ).append(")<br />")
# .append("UNSIGNED_PAYLOAD : ").append("ENC(").append( jasyptEncoding(UNSIGNED_PAYLOAD) ).append(")<br />")
# .append("REGION_NAME     : ").append("ENC(").append( jasyptEncoding(REGION_NAME) ).append(")<br />")
# .append("ENDPOINT_SEOUL  : ").append("ENC(").append( jasyptEncoding(ENDPOINT_SEOUL) ).append(")<br />")
# ...

# %%
ports = \
'''443
443
32754
9888
46004
32722
46004
443
32383
46004
31236
46004
8080
30511
46004
30753
46004
8080
31572'''

# %%
set(ports.split('\n'))
# Out:
# {'30511',
#  '30753',
#  '31236',
#  '31572',
#  '32383',
#  '32722',
#  '32754',
#  '443',
#  '46004',
#  '8080',
#  '9888'}

# %%
txt = \
'''
Dependency	Version
jekyll	3.9.3
github-pages-health-check	1.17.9
github-pages	228
html-pipeline	2.14.3
jekyll-avatar	0.7.0
jekyll-coffeescript	1.1.1
jekyll-commonmark-ghpages	0.4.0
jekyll-default-layout	0.1.4
jekyll-feed	0.15.1
jekyll-gist	1.5.0
jekyll-github-metadata	2.13.0
jekyll-include-cache	0.2.1
jekyll-mentions	1.6.0
jekyll-optional-front-matter	0.3.2
jekyll-paginate	1.1.0
jekyll-readme-index	0.3.0
jekyll-redirect-from	0.16.0
jekyll-relative-links	0.6.1
jekyll-remote-theme	0.4.3
jekyll-sass-converter	1.5.2
jekyll-seo-tag	2.8.0
jekyll-sitemap	1.4.0
jekyll-swiss	1.0.0
jekyll-theme-architect	0.2.0
jekyll-theme-cayman	0.2.0
jekyll-theme-dinky	0.2.0
jekyll-theme-hacker	0.2.0
jekyll-theme-leap-day	0.2.0
jekyll-theme-merlot	0.2.0
jekyll-theme-midnight	0.2.0
jekyll-theme-minimal	0.2.0
jekyll-theme-modernist	0.2.0
jekyll-theme-primer	0.6.0
jekyll-theme-slate	0.2.0
jekyll-theme-tactile	0.2.0
jekyll-theme-time-machine	0.2.0
jekyll-titles-from-headings	0.5.3
jemoji	0.12.0
kramdown-parser-gfm	1.1.0
kramdown	2.3.2
liquid	4.0.4
minima	2.5.1
nokogiri	1.15.4
rouge	3.26.0
ruby	2.7.4
safe_yaml	1.0.5
sass	3.7.4
'''

# %%
for package, version in map(lambda x: x.split('\t'), txt.split('\n')[2:-1]):
    print( f'gem \'{package}\', \'~> {version}\'')
# Out:
# gem 'jekyll', '~> 3.9.3'
# gem 'github-pages-health-check', '~> 1.17.9'
# gem 'github-pages', '~> 228'
# gem 'html-pipeline', '~> 2.14.3'
# gem 'jekyll-avatar', '~> 0.7.0'
# gem 'jekyll-coffeescript', '~> 1.1.1'
# gem 'jekyll-commonmark-ghpages', '~> 0.4.0'
# gem 'jekyll-default-layout', '~> 0.1.4'
# gem 'jekyll-feed', '~> 0.15.1'
# gem 'jekyll-gist', '~> 1.5.0'
# gem 'jekyll-github-metadata', '~> 2.13.0'
# gem 'jekyll-include-cache', '~> 0.2.1'
# gem 'jekyll-mentions', '~> 1.6.0'
# gem 'jekyll-optional-front-matter', '~> 0.3.2'
# gem 'jekyll-paginate', '~> 1.1.0'
# gem 'jekyll-readme-index', '~> 0.3.0'
# gem 'jekyll-redirect-from', '~> 0.16.0'
# gem 'jekyll-relative-links', '~> 0.6.1'
# gem 'jekyll-remote-theme', '~> 0.4.3'
# gem 'jekyll-sass-converter', '~> 1.5.2'
# gem 'jekyll-seo-tag', '~> 2.8.0'
# gem 'jekyll-sitemap', '~> 1.4.0'
# gem 'jekyll-swiss', '~> 1.0.0'
# gem 'jekyll-theme-architect', '~> 0.2.0'
# gem 'jekyll-theme-cayman', '~> 0.2.0'
# ...
